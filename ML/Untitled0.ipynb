# %%
print ("hello world")
# Out:
# hello world

# %%
print ("Emon Karmoker")
# Out:
# Emon Karmoker

# %%
print ("abcd",123, 25,17)
# Out:
# abcd 123 25 17

# %%
x=10
y=15.10
z='another string'
print (x)
x='asda'
print (x)
# Out:
# 10
# asda

# %%
#f-string
print (f"value of x is {x}")
# Out:
# value of x is asda

# %%
x=input()
print (f'input was {x}')
# Out:
# 45
# input was 45

# %%
x=input()
y=input()
print (x+y)
# Out:
# 45
# 98
# 4598

# %%
name = "Mary"
age = 25

# "Mary is aged 25"

formstr = f"{name} is aged {age}"
print(formstr)
# Out:
# Mary is aged 25

# %%
n = int(input())

# if(n%2==0){
    
# }

if n%2==0:
  print("Even")
  print('Inside of even')
else:
  print("Odd")
  print('Inside of else')
  
print('Outside of indentation')
# Out:
# 55
# Odd
# Inside of else
# Outside of indentation

# %%
n = 55

if n>100:
  print("Greater than 100")
elif n>50:
  print("Greater than 50 but less than 100")
else:
  print("less than 50")
# Out:
# Greater than 50 but less than 100

# %%
n = 5

if 10<=n<=100:
  print("number is between 10 and 100 inclusive")
else:
  print("outside of that range")
# Out:
# outside of that range

# %%
year=int(input("Enter year to be checked:"))
if(year%4==0 and year%100!=0 or year%400==0):
    print("The year is a leap year!")
else:
    print("The year isn't a leap year!")
# Out:
# The year isn't a leap year!

# %%
#for (i=0; i<10;i++)
#for i in range(10):
#for (i=5;i<10;i++)
#for i in range(5,10):
#for (i=5;i<10;i+2)
#for i in range(5,10,2):

for i in range(5,10,2):

print (i)

# %%
for i in range (3,100,3)
print (i)
# Out:
#   File "<ipython-input-30-5c31b5db58e4>", line 1
#     for i in range(3,100,3)
#                            ^
# SyntaxError: expected ':'
