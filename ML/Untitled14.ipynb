# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from util_functions import *
from preprocessing_Dataset1 import *
from train_eval import *
from models import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-84d8db9121a2> in <cell line: 1>()
# ----> 1 from util_functions import *
#       2 from preprocessing_Dataset1 import *
#       3 from train_eval import *
#       4 from models import *
#
# ModuleNotFoundError: No module named 'util_functions'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import sys
sys.path.append('/path/to/your/custom/modules')
